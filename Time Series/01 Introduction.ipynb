# %% [markdown]
# # Introduction to Time Series Analysis
#
# In this lesson, we introduce the fundamentals of time series analysis. We discuss what a time series is, its key components, and real-world applications.

# %% [markdown]
# ## What is a Time Series?
#
# A time series is a sequence of observations recorded over time. It is used in many fields including finance, economics, weather forecasting, and more.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib inline

# Generate synthetic time series data
dates = pd.date_range(start='2020-01-01', periods=100, freq='D')
data = np.sin(np.linspace(0, 3 * np.pi, 100)) + np.random.normal(0, 0.5, 100)
ts_df = pd.DataFrame({'Date': dates, 'Value': data}).set_index('Date')

# Plot the time series
plt.figure(figsize=(12,6))
plt.plot(ts_df, label='Synthetic Time Series')
plt.title('Introduction to Time Series Analysis')
plt.xlabel('Date')
plt.ylabel('Value')
plt.legend()
plt.show()

# %% [markdown]
# ## Conclusion
#
# This lesson provided a brief overview of time series data and its applications. In the next lessons, we will explore visualization, decomposition, and various modeling techniques.
